# %% [markdown]
# # **Just for Test**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure()
ax = plt.axes()

names = ['size_nn = 128', 'size_nn = 256', 'size_nn = 512','size_nn = 1024' ]

value_S_P = [0.006, 0.007, 0.007,0.011]
value_N_P = [0.02, 0.023, 0.023,0.028]
value_S_R = [0.003, 0.011, 0.013,0.012]
value_N_R = [0.037, 0.024, 0.03,0.029]
value_SC = [0.033, 0.031, 0.033,0.035]
value_H_1 = [0.014, 0.011, 0.011,0.012]
value_H_2 = [0.014, 0.01, 0.011,0.017]

plt.xlabel('Number of size in neural network')
plt.ylabel('Mean Negative Log-Likelihood')

plt.plot(names, value_S_P, label='S_Poisson')
plt.plot(names, value_N_P, label='N_Poisson')
plt.plot(names, value_S_R, label='S_Renewal')
plt.plot(names, value_N_R, label='N_Renewal')
plt.plot(names, value_SC, label='SC')
plt.plot(names, value_H_1, label='Hawkws1')
plt.plot(names, value_H_2, label='Hawkws2')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [12.8, 4.8] )
ax = plt.axes()

names = ['size_nn = 2', 'size_nn = 4', 'size_nn = 8','size_nn = 16','size_nn = 32','size_nn = 64','size_nn = 128', 'size_nn = 256', 'size_nn = 512','size_nn = 1024' ]

value_S_P = [0.004,0.007,-0.004,0.002,-0.007,0.012,0.006, 0.007, 0.007,0.011]
value_N_P = [0.021,0.025,0.017,0.016,0.023,0.0309,0.02, 0.023, 0.023,0.028]
value_S_R = [0.003,0.003,0.001,0.001,0.001,0.004,0.003, 0.011, 0.013,0.012]
value_N_R = [0.032,0.02,0.023,0.021,0.018,0.021,0.037, 0.024, 0.03,0.029]
value_SC = [0.04,0.035,0.033,0.027,0.027,0.035,0.033, 0.031, 0.033,0.035]
value_H_1 = [0.019,0.009,0.008,0.006,0.007,0.009,0.014, 0.011, 0.011,0.012]
value_H_2 = [0.028,0.018,0.014,0.014,0.008,0.015,0.014, 0.01, 0.011,0.017]

plt.xlabel('Number of Size in Neural Network')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Mean Negative Log-Likelihood VS Number of Size in Neural Network in Seven Random Processes')

plt.plot(names, value_S_P,marker='o', label='S_Poisson')
plt.plot(names, value_N_P, marker='o',label='N_Poisson')
plt.plot(names, value_S_R,marker='o', label='S_Renewal')
plt.plot(names, value_N_R,marker='o', label='N_Renewal')
plt.plot(names, value_SC, marker='o',label='SC')
plt.plot(names, value_H_1, marker='o',label='Hawkws1')
plt.plot(names, value_H_2,marker='o', label='Hawkws2')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **Graphs in nn size change**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]

value_S_P = [-0.01,0.004,0.007,-0.004,0.002,-0.007,0.012,0.006, 0.007, 0.007,0.011]
value_N_P = [0.016,0.021,0.025,0.017,0.016,0.023,0.0309,0.02, 0.023, 0.023,0.028]
value_S_R = [0.01,0.003,0.003,0.001,0.001,0.001,0.004,0.003, 0.011, 0.013,0.012]
value_N_R = [0.022,0.032,0.02,0.023,0.021,0.018,0.021,0.037, 0.024, 0.03,0.029]
value_SC = [0.028,0.04,0.035,0.033,0.027,0.027,0.035,0.033, 0.031, 0.033,0.035]
value_H_1 = [0.012,0.019,0.009,0.008,0.006,0.007,0.009,0.014, 0.011, 0.011,0.012]
value_H_2 = [0.013,0.028,0.018,0.014,0.014,0.008,0.015,0.014, 0.01, 0.011,0.017]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Mean Negative Log-Likelihood VS Number of Size in Neural Network in Seven Random Processes')

plt.plot(names, value_S_P,marker='o', label='S_Poisson')
plt.plot(names, value_N_P, marker='o',label='N_Poisson')
plt.plot(names, value_S_R,marker='o', label='S_Renewal')
plt.plot(names, value_N_R,marker='o', label='N_Renewal')
plt.plot(names, value_SC, marker='o',label='SC')
plt.plot(names, value_H_1, marker='o',label='Hawkws1')
plt.plot(names, value_H_2,marker='o', label='Hawkws2')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [-0.001]*11
value_exponential = [0.000]*11
value_piecewise = [0.002]*11
value_NN = [-0.01,0.004,0.007,-0.004,0.002,-0.007,0.012,0.006, 0.007, 0.007,0.011]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Stationary Poisson Process (S-Poisson)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.0205]*11
value_exponential = [0.0215]*11
value_piecewise = [0.023]*11
value_NN = [0.016,0.021,0.025,0.017,0.016,0.023,0.0309,0.02, 0.023, 0.023,0.028]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Non-stationary Poisson Process (N-Poisson)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.766]*11
value_exponential = [0.298]*11
value_piecewise = [0.574]*11
value_NN = [0.01,0.003,0.003,0.001,0.001,0.001,0.004,0.003, 0.011, 0.013,0.012]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Stationary Renewal Process (S-Renewal)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.368]*11
value_exponential = [0.355]*11
value_piecewise = [0.336]*11
value_NN = [0.022,0.032,0.02,0.023,0.021,0.018,0.021,0.037, 0.024, 0.03,0.029]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Non-stationary Renewal Process (N-Renewal)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.180]*11
value_exponential = [0.029]*11
value_piecewise = [0.038]*11
value_NN = [0.022,0.032,0.02,0.023,0.021,0.018,0.021,0.037, 0.024, 0.03,0.029]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Self-correcting Process (SC)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.213]*11
value_exponential = [0.073]*11
value_piecewise = [0.013]*11
value_NN = [0.012,0.019,0.009,0.008,0.006,0.007,0.009,0.014, 0.011, 0.011,0.012]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Hawkes Processes 1 (Hawkes1)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['no hidden layer','2', '4', '8','16','32','64(Original)','128', '256', '512','1024' ]


value_constant = [0.671]*11
value_exponential = [0.413]*11
value_piecewise = [0.205]*11
value_NN = [0.013,0.028,0.018,0.014,0.014,0.008,0.015,0.014, 0.01, 0.011,0.017]

plt.xlabel('Number of Units in each Neural Network Hidden Layer')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Hawkes Processes 2 (Hawkes2)')

plt.plot(names, value_constant,linestyle=':', label='constand model')
plt.plot(names, value_exponential, linestyle='--',label='exponential model ')
plt.plot(names, value_piecewise,linestyle='-.', label='piecewise constant model')
plt.plot(names, value_NN,marker='o', label='neural network based model ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **Remove Positive Limitation VS Original**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [12.8, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkws1','Hawkws2' ]



value_Original = [0.012,0.030,0.004,0.021,0.035,0.009,0.015]
value_Remove = [0.004,0.014,0.002,0.021,0.029,0.009,0.01]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('Positive Limitation Removed VS Positive Limitation Kept Neural Networks ')

plt.plot(names, value_Original,marker='o',linestyle='--', label='Positive Limitation Kept (Original)')
plt.plot(names, value_Remove, marker='o',label='Positive Limitation Removed ')




plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **nn_size = 64 Add nn layers**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkws1','Hawkws2' ]


value_2 = [0.012,0.030,0.004,0.021,0.035,0.009,0.015]
value_3 = [0.008,0.022,0.001,0.029,0.051,0.008,0.022]
value_4 = [0.018,0.02,0.002,0.025,0.039,0.016,0.014]
value_5 = [0.018,0.026,0.015,0.029,0.038,0.027,0.013]
value_6 = [0.016,0.024,0.019,0.026,0.044,0.02,0.015]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' Fixed Number of Units in each Neural Network Hidden Layer = 64 and Increase the Number of Hidden Layers ')

plt.plot(names, value_2,marker='o',linestyle='--', label='Number of layers = 2 (Original)')
plt.plot(names, value_3, marker='o',label='Number of layers = 3 ')

plt.plot(names, value_4,marker='o',linestyle=':', label='Number of layers = 4')
plt.plot(names, value_5, marker='o',linestyle='-.',label='Number of layers = 5 ')

plt.plot(names, value_6, marker='o',linestyle=':',label='Number of layers = 6 ')



plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **nn_size = 1024 Add nn layers**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkws1','Hawkws2' ]

value_2O = [0.012,0.030,0.004,0.021,0.035,0.009,0.015]
value_2 = [-0.005,0.026,0.011,0.03,0.042,0.01,0.015]
value_3 = [0.012,22.325,0.014,0.072,22.269,22.524,0.014]
value_4 = [0.084,0.024,0.024,0.031,0.039,0.017,0.02]
value_5 = [0.033,22.315,0.074,0.027,0.126,22.543,23.052]


plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' Fixed Number of Units in each Neural Network Hidden Layer = 1024 and Increase the Number of Hidden Layers ')

plt.plot(names, value_2O,marker='o',linestyle='--', label='Number of layers = 2 and Number of Units in Hidden Layers = 64 (Original)')
plt.plot(names, value_2,marker='o',linestyle='--', label='Number of layers = 2 ')
plt.plot(names, value_3, marker='o',label='Number of layers = 3 ')

plt.plot(names, value_4,marker='o',linestyle=':', label='Number of layers = 4')
plt.plot(names, value_5, marker='o',linestyle='-.',label='Number of layers = 5 ')





plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **Activation func. and lr**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]


value_tanh = [-0.003,	0.025,	0.001,	0.02,	0.031,	0.012,	0.01]
value_relu = [2.255,	0.59,	0.078, 0.297,	2.94,	1.212,	0.924]
value_sigmoid = [-0.007,	0.022,	0.008,	0.026,	0.055,	0.011,	0.017]
value_softplus = [-0.003,	0.026,	0.01,	0.027,	0.04,	0.013,	0.031]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of neural network based model with different activation functions ')

plt.plot(names, value_tanh,linestyle=':', label='tanh')
plt.plot(names, value_relu, linestyle='--',label='relu ')
plt.plot(names, value_sigmoid,linestyle='-.', label='sigmoid')
plt.plot(names, value_softplus,marker='o', label='softplus ')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_tanh = [-0.005,	0.016,	0.76,	0.371,	0.182,	0.213,	0.673]
value_relu = [0.005,	0.015,	0.715,	0.367,	0.181,	0.231,	0.67]
value_sigmoid = [-0.016,	0.016,	0.813,	0.366,	0.182,	0.215,	0.638]
value_softplus = [-0.01,	0.021,	0.753,	0.378,	0.187,	0.222,	0.659]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of constant model with different activation functions ')

plt.plot(names, value_tanh,linestyle=':', label='tanh')
plt.plot(names, value_relu, linestyle='--',label='relu ')
plt.plot(names, value_sigmoid,linestyle='-.', label='sigmoid')
plt.plot(names, value_softplus,marker='o', label='softplus ')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_tanh = [-0.005,	0.015,	0.287,	0.359,	0.032,	0.073,	0.39]
value_relu = [0.005,	0.017,	0.279,	0.355,	0.034,	0.086,	0.397]
value_sigmoid = [-0.015,	0.014,	0.315,	0.372,	0.033,	0.073,	0.376]
value_softplus = [-0.01,	0.022,	0.297,	0.363,	0.032,	0.075,	0.392]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of exponential model with different activation functions ')

plt.plot(names, value_tanh,linestyle=':', label='tanh')
plt.plot(names, value_relu, linestyle='--',label='relu ')
plt.plot(names, value_sigmoid,linestyle='-.', label='sigmoid')
plt.plot(names, value_softplus,marker='o', label='softplus ')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_tanh = [-0.001,	0.016,	0.434,	0.34,	0.042,	0.021,	0.199]
value_relu = [0.008,	0.014,	0.431,	0.328,	0.043,	0.021,	0.189]
value_sigmoid = [-0.012,	0.03,	0.516,	0.355,	0.041,	0.011,	0.218]
value_softplus = [-0.007,	0.023,	0.534,	0.337,	0.039,	0.013,	0.206]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of piecewise constant model with different activation functions ')

plt.plot(names, value_tanh,linestyle=':', label='tanh')
plt.plot(names, value_relu, linestyle='--',label='relu ')
plt.plot(names, value_sigmoid,linestyle='-.', label='sigmoid')
plt.plot(names, value_softplus,marker='o', label='softplus ')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8])
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_01 = [-0.003,	0.025,	0.001,	0.02,	0.031,	0.012,	0.01]
value_001 = [0.018,	0.039,	0.003,	0.043,	0.045,	0.013,	0.03]
value_005 = [-0.012,	0.018,	0.006,	0.022,	0.032,	0.007,	0.012]
value_0001 = [0.009,	0.022,	0.002,	0.02,	0.026,	0.008,	0.016]
value_0005 = [-0.008,	0.032,	0.006,	0.041,	0.036,	0.007,	0.015]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of neural network based model with different learning rates')

plt.plot(names, value_01,linestyle=':', label='lr = 0.1')
plt.plot(names, value_001,marker='o', label='lr = 0.01 ')
plt.plot(names, value_005, linestyle='--',label='lr = 0.05 ')
plt.plot(names, value_0001,linestyle='-.', label='lr = 0.001')
plt.plot(names, value_0005,marker='o', label='lr = 0.005')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_01 = [-0.005,	0.016,	0.76,	0.371,	0.182,	0.213,	0.673]
value_001 = [0.014,	0.037,	0.713,	0.381,	0.185,	0.254,	0.718]
value_005 = [-0.013,	0.014,	0.751,	0.375,	0.182,	0.214,	0.66]
value_0001 = [0.006,	0.017,	0.746,	0.376,	0.182,	0.215,	0.653]
value_0005 = [-0.009,	0.034,	0.721,	0.371,	0.179,	0.227,	0.658]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of constant model with different learning rates')

plt.plot(names, value_01,linestyle=':', label='lr = 0.1')
plt.plot(names, value_001,marker='o', label='lr = 0.01 ')
plt.plot(names, value_005, linestyle='--',label='lr = 0.05 ')
plt.plot(names, value_0001,linestyle='-.', label='lr = 0.001')
plt.plot(names, value_0005,marker='o', label='lr = 0.005')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_01 = [-0.005,	0.015,	0.287,	0.359,	0.032,	0.073,	0.39]
value_001 = [0.013,	0.032,	0.281,	0.38,	0.033,	0.087,	0.408]
value_005 = [-0.013,	0.016,	0.284,	0.367,	0.031,	0.073,	0.391]
value_0001 = [0.006,	0.015,	0.289,	0.371,	0.027,	0.072,	0.39]
value_0005 = [-0.009,	0.031,	0.283,	0.366,	0.029,	0.081,	0.406]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of exponential model with different learning rates')

plt.plot(names, value_01,linestyle=':', label='lr = 0.1')
plt.plot(names, value_001,marker='o', label='lr = 0.01 ')
plt.plot(names, value_005, linestyle='--',label='lr = 0.05 ')
plt.plot(names, value_0001,linestyle='-.', label='lr = 0.001')
plt.plot(names, value_0005,marker='o', label='lr = 0.005')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_01 = [-0.001,	0.016,	0.434,	0.34,	0.042,	0.021,	0.199]
value_001 = [0.015,	0.049,	0.432,	0.36,	0.061,	0.031,	0.24]
value_005 = [-0.011,	0.017,	0.495,	0.353,	0.042,	0.01,	0.187]
value_0001 = [0.008,	0.015,	0.434,	0.334,	0.044,	0.014,	0.187]
value_0005 = [-0.007,	0.034,	0.441,	0.343,	0.05,	0.025,	0.246]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title(' MNLL of piecewise constant model with different learning rates')

plt.plot(names, value_01,linestyle=':', label='lr = 0.1')
plt.plot(names, value_001,marker='o', label='lr = 0.01 ')
plt.plot(names, value_005, linestyle='--',label='lr = 0.05 ')
plt.plot(names, value_0001,linestyle='-.', label='lr = 0.001')
plt.plot(names, value_0005,marker='o', label='lr = 0.005')


plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # **Training size**

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_20 = [0.696,	0.718,	0.94,	0.407,	0.508,	0.881,	0.98]
value_40 = [0.693,	0.715,	0.95,	0.407,	0.5,	0.849,	0.918]
value_60 = [0.693,	0.719,	0.942,	0.4,	0.499,	0.895,	0.945]
value_80 = [0.699,	0.713,	0.955,	0.396,	0.496,	0.835,	0.993]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('MNLL in neural network based model VS Random Processes with different training size ')

plt.plot(names, value_20,linestyle=':', label='training size = 20% ')
plt.plot(names, value_40, linestyle='--',label='training size = 40% ')
plt.plot(names, value_60,linestyle='-.', label='training size = 60%')
plt.plot(names, value_80,marker='o', label='training size = 80% ')

plt.savefig('trainsize1.jpg')
plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_20 = [0.695,	0.726,	1.035,	0.432,	0.507,	0.881,	0.985]
value_40 = [0.693,	0.731,	1.003,	0.436,	0.506,	0.848,	0.922]
value_60 = [0.693,	0.728,	0.988,	0.428,	0.496,	0.896,	0.952]
value_80 = [0.698,	0.715,	1.028,	0.423,	0.499,	0.836,	0.996]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('MNLL in piecewise constant model VS Random Processes with different training size ')

plt.plot(names, value_20,linestyle=':', label='training size = 20% ')
plt.plot(names, value_40, linestyle='--',label='training size = 40% ')
plt.plot(names, value_60,linestyle='-.', label='training size = 60%')
plt.plot(names, value_80,marker='o', label='training size = 80% ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_20 = [0.697,	0.725,	0.965,	0.439,	0.508,	0.884,	0.996]
value_40 = [0.693,	0.73,	0.972,	0.439,	0.5,	0.853,	0.939]
value_60 = [0.693,	0.727,	0.965,	0.437,	0.497,	0.9,	0.964]
value_80 = [0.698,	0.709,	0.976,	0.444,	0.498,	0.842,	1.011]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('MNLL in exponential model VS Random Processes with different training size ')

plt.plot(names, value_20,linestyle=':', label='training size = 20% ')
plt.plot(names, value_40, linestyle='--',label='training size = 40% ')
plt.plot(names, value_60,linestyle='-.', label='training size = 60%')
plt.plot(names, value_80,marker='o', label='training size = 80% ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure(figsize = [14.2, 4.8] )
ax = plt.axes()

names = ['S_Poisson','N_Poisson', 'S_Renewal', 'N_Renewal','SC','Hawkes1','Hawkes2' ]

value_20 = [0.698,	0.721,	1.126,	0.452,	0.536,	0.943,	1.073]
value_40 = [0.693,	0.716,	1.151,	0.435,	0.539,	0.908,	1.063]
value_60 = [0.693,	0.72,	1.124,	0.448,	0.532,	0.973,	1.071]
value_80 = [0.698,	0.714,	1.146,	0.438,	0.54,	0.902,	1.135]

plt.xlabel('Random Processes')
plt.ylabel('Mean Negative Log-Likelihood')
plt.title('MNLL in constant model VS Random Processes with different training size ')

plt.plot(names, value_20,linestyle=':', label='training size = 20% ')
plt.plot(names, value_40, linestyle='--',label='training size = 40% ')
plt.plot(names, value_60,linestyle='-.', label='training size = 60%')
plt.plot(names, value_80,marker='o', label='training size = 80% ')

plt.legend(loc=' right',bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Unrecognized location ' right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
